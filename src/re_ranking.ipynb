# %% [markdown]
# # AIR - Exercise in Google Colab
#
# ## Colab Preparation
#
# Open via google drive -> right click: open with Colab
#
# **Get a GPU**
#
# Toolbar -> Runtime -> Change Runtime Type -> GPU
#
# **Mount Google Drive**
#
# * Download data and clone your github repo to your Google Drive folder
# * Use Google Drive as connection between Github and Colab (Could also use direct github access, but re-submitting credentials might be annoying)
# * Commit to Github locally from the synced drive
#
# **Keep Alive**
#
# When training google colab tends to kick you out, This might help: https://medium.com/@shivamrawat_756/how-to-prevent-google-colab-from-disconnecting-717b88a128c0
#
# **Get Started**
#
# Run the following script to mount google drive and install needed python packages. Pytorch comes pre-installed.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/AIR/
#! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.12.0-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.12.0-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.12.0-Linux-x86_64.sh -b -f -p /content/drive/MyDrive/AIR/Miniconda

# !source /content/drive/MyDrive/AIR/Miniconda/bin/activate #to activate the miniconda environment

# %env PYTHONPATH= '/content/drive/MyDrive/AIR/Miniconda/bin/python
# !echo $PYTHONPATH

#Add miniconda to the system PATH:

import sys
sys.path.append('/content/drive/MyDrive/AIR/Miniconda/lib/python3.7/site-packages/')

import os # ?? needed?
path = '/content/drive/MyDrive/AIR/Miniconda/bin:' + os.environ['PATH']
# %env PATH=$path

# %cd /content/drive/MyDrive/AIR/condaENVair
# !conda create --name MYcondaENVair python=3.6

# %cd /content/drive/MyDrive/AIR/condaENVair
# !source activate MYcondaENVair

# !conda info --envs

# !conda install --channel defaults conda python=3.6 --yes
# !conda update --channel defaults --all --yes

# !pip install -r /content/drive/MyDrive/AIR/requirements.txt

# !conda install pytorch==1.6.0 torchvision==0.7.0 -c pytorch

# %%
import torch

print("Version:",torch.__version__)
print("Has GPU:",torch.cuda.is_available()) # check that 1 gpu is available
print("Random tensor:",torch.rand(10,device="cuda")) # check that pytorch works

# %% [markdown]
# # Main.py Replacement
#
# -> add your code here
#
# - Replace *air_test* with your google drive location in the sys.path.append()

# %% [markdown]
# #Config

# %%
import sys
sys.path.append('/content/drive/MyDrive/AIR/src')

from allennlp.common import Params, Tqdm
from allennlp.common.util import prepare_environment
from allennlp.data.dataloader import PyTorchDataLoader
prepare_environment(Params({})) # sets the seeds to be fixed

import pandas as pd
import torch
import torch.optim as optim
import torch.nn as nn

from allennlp.data.vocabulary import Vocabulary
from allennlp.modules.token_embedders import Embedding
from allennlp.modules.text_field_embedders import BasicTextFieldEmbedder

from data_loading import *
from model_knrm import *
from model_tk import *
from core_metrics import *

# change paths to your data directory
config = {
    "vocab_directory": "../AIR/data/Part-2/allen_vocab_lower_10",
    "pre_trained_embedding": "../AIR/data/Part-2/glove.42B.300d.txt",
    "model": "tk",
    "train_data": "../AIR/data/Part-2/triples.train.tsv",
    "validation_data": "../AIR/data/Part-2/msmarco_tuples.validation.tsv",
    "test_data": "../AIR/data/Part-2/msmarco_tuples.test.tsv",
    "fira_test_data": "../AIR/data/Part-2/fira-22.tuples.tsv",
    "qrels": "../AIR/data/Part-2/msmarco_qrels.txt",
    "fira_qrels": "../AIR/data/Part-1/fira-22.baseline-qrels.tsv",
    "custom_qrels": "../AIR/data/Part-1/aggregated_qrels.tsv",
    "custom_qrels_log": "../AIR/data/Part-1/aggregated_qrels_log.tsv",
    "model_path": "../AIR/data/Part-2/model_weights_tk.pth"
}

#
# data loading
#
vocab_directory = config["vocab_directory"]
print("Expected vocabulary directory:", os.path.abspath(vocab_directory))

vocab = Vocabulary.from_files(config["vocab_directory"])
tokens_embedder = Embedding(vocab=vocab,
                           pretrained_file= config["pre_trained_embedding"],
                           embedding_dim=300,
                           trainable=True,
                           padding_index=0)
word_embedder = BasicTextFieldEmbedder({"tokens": tokens_embedder})

# recommended default params for the models (but you may change them if you want)
if config["model"] == "knrm":
    model = KNRM(word_embedder, n_kernels=11)
elif config["model"] == "tk":
    model = TK(word_embedder, n_kernels=11, n_layers = 2, n_tf_dim = 300, n_tf_heads = 10)

# put model to gpu
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# optimizer, loss
optimizer = optim.Adam(model.parameters(), lr=4e-5)
loss_function = nn.MarginRankingLoss(margin=1.0)

# print model struct
print('Model', config["model"], 'total parameters:', sum(p.numel() for p in model.parameters() if p.requires_grad))
print('Network:', model)
# Out:
# Expected vocabulary directory: /content/drive/MyDrive/AIR/data/Part-2/allen_vocab_lower_10
# 1917494it [01:22, 23133.62it/s]
# Model tk total parameters: 97569520
# Network: TK(
#   (word_embeddings): BasicTextFieldEmbedder(
#     (token_embedder_tokens): Embedding()
#   )
#   (positional_encoding): PositionalEncoding()
#   (transformer): TransformerEncoder(
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=300, out_features=300, bias=True)
#         )
#         (linear1): Linear(in_features=300, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=300, bias=True)
#         (norm1): LayerNorm((300,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((300,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (log_norm_layer): Linear(in_features=11, out_features=1, bias=False)
#   (length_norm_layer): Linear(in_features=11, out_features=1, bias=False)
#   (out): Linear(in_features=2, out_features=1, bias=False)
# )

# %% [markdown]
# # Define train/eval functions

# %%
def train_model(train_loader):

    model.train()
    total_loss = 0.0
    num_batches = 0

    for batch in Tqdm.tqdm(train_loader):

        #set grad to 0
        optimizer.zero_grad()

        #put data to device
        query = batch['query_tokens']['tokens']['tokens'].to(device)
        doc_pos = batch['doc_pos_tokens']['tokens']['tokens'].to(device)
        doc_neg = batch['doc_neg_tokens']['tokens']['tokens'].to(device)

        #get score for relevant and nonrelevant document
        score_pos = model(query, doc_pos)
        score_neg = model(query, doc_neg)

        #make targets
        target = torch.ones(score_pos.size(), device = score_pos.device)

        #compute loss
        loss = loss_function(score_pos, score_neg, target)
        total_loss += loss.item()

        #backprop
        loss.backward()
        optimizer.step()
        num_batches = num_batches + 1

    return total_loss / num_batches

def evaluate_model(eval_loader, qrels):

    # put model to eval mode
    model.eval()
    ranking = {}

    with torch.no_grad():
      for batch in Tqdm.tqdm(eval_loader):

        # data
        query = batch['query_tokens']['tokens']['tokens'].to(device)
        doc = batch['doc_tokens']['tokens']['tokens'].to(device)

        # get scores
        scores = model(query, doc).squeeze()

        # append scores with documents to queries
        for i in range(len(scores)):

            query_id = batch['query_id'][i]
            doc_id = batch['doc_id'][i]

            if query_id not in ranking:
                ranking[query_id] = []
            ranking[query_id].append((doc_id, scores[i].item()))

    # core_metrics.py functions, calculate metrics
    ranked_results = unrolled_to_ranked_result(ranking)
    eval_metrics = calculate_metrics_plain(ranked_results, qrels)
    return eval_metrics, ranked_results

# %% [markdown]
# # Instance dataloaders

# %%
# read train data, instance dataloader
train_reader = IrTripleDatasetReader(lazy=True, max_doc_length=180, max_query_length=30)
train_data = train_reader.read(config["train_data"])
train_data.index_with(vocab)
train_loader = PyTorchDataLoader(train_data, batch_size=256)

# read val data, instance dataloader
val_reader = IrLabeledTupleDatasetReader(lazy=True, max_doc_length=180, max_query_length=30)
val_data = val_reader.read(config["validation_data"])
val_data.index_with(vocab)
val_loader = PyTorchDataLoader(val_data, batch_size=256)

# read test data, instance dataloader
test_reader = IrLabeledTupleDatasetReader(lazy=True, max_doc_length=180, max_query_length=30)
test_data = val_reader.read(config["test_data"])
test_data.index_with(vocab)
test_loader = PyTorchDataLoader(test_data, batch_size=256)

# read fira data, instance dataloader
fira_reader = IrLabeledTupleDatasetReader(lazy=True, max_doc_length=180, max_query_length=30)
fira_data = val_reader.read(config["fira_test_data"])
fira_data.index_with(vocab)
fira_loader = PyTorchDataLoader(fira_data, batch_size=256)

# read qrels
qrels = load_qrels(config["qrels"])
fira_qrels = load_qrels(config["fira_qrels"])
custom_qrels = load_qrels(config["custom_qrels"])
custom_qrels_log = load_qrels(config["custom_qrels_log"])

# %% [markdown]
# # Run training

# %%
# for visualizing for report
train_loss_per_epoch = []
val_metrics_per_epoch = []

num_epochs = 10
best_mrr = 0
patience = 2
no_improvement_cnt = 0

for epoch in range(num_epochs):

    train_loss = train_model(train_loader)
    train_loss_per_epoch.append(train_loss)
    print(f"Epoch {epoch + 1}: Training Loss = {train_loss:.4f}")

    val_metrics, _ = evaluate_model(val_loader, qrels)
    val_metrics_per_epoch.append(val_metrics)
    print(f"Validation Metrics: {val_metrics}")

    #early stopping based on mrr@10 values
    curr_epoch_mrr = val_metrics.get("MRR@10", 0)
    if curr_epoch_mrr > best_mrr:
        best_mrr = curr_epoch_mrr
        no_improvement_cnt = 0
        torch.save(model.state_dict(), config["model_path"])
    else:
        no_improvement_cnt = no_improvement_cnt + 1
        if no_improvement_cnt >= patience:
            print(f"Stopped early at epoch {epoch + 1}")
            break

# %% [markdown]
# Save metrics from training

# %%
train_loss_df = pd.DataFrame(train_loss_per_epoch, columns=['loss'])
train_loss_df.to_csv("/content/drive/MyDrive/AIR/data/Part-2/train_loss_tk.csv", index=False)

val_metrics_df = pd.DataFrame(val_metrics_per_epoch)
val_metrics_df.to_csv("/content/drive/MyDrive/AIR/data/Part-2/val_metrics_tk.csv", index=False)

# %% [markdown]
# # Evaluate on test sets

# %%
msmarco_test_eval, ranked_results = evaluate_model(test_loader, qrels)
fira_test_eval, _ = evaluate_model(fira_loader, fira_qrels)
custom_fira_eval, _ = evaluate_model(fira_loader, custom_qrels)

print(f"MSMarco metrics: {msmarco_test_eval}")
print(f"Fira metrics: {fira_test_eval}")
print(f"Custom Fira metrics: {custom_fira_eval}")
# Out:
# 0it [00:00, ?it/s]
# 1it [00:00,  7.56it/s]
# reading instances: 256it [00:00, 1972.80it/s]
# 2it [00:00,  4.30it/s]
# 3it [00:00,  5.68it/s]
# 4it [00:00,  6.65it/s]
# 5it [00:00,  6.70it/s]
# 6it [00:00,  7.38it/s]
# reading instances: 1536it [00:00, 1887.56it/s]
# 7it [00:01,  5.27it/s]
# 8it [00:01,  6.04it/s]
# 9it [00:01,  6.80it/s]
# 10it [00:01,  7.50it/s]
# 11it [00:01,  7.96it/s]
# 12it [00:01,  8.39it/s]
# reading instances: 3072it [00:01, 2139.56it/s]
# 13it [00:02,  5.80it/s]
# 14it [00:02,  6.43it/s]
# 15it [00:02,  6.95it/s]
# 16it [00:02,  7.47it/s]
# 17it [00:02,  7.86it/s]
# 18it [00:02,  8.19it/s]
# reading instances: 4608it [00:02, 2071.47it/s]
# 19it [00:02,  5.73it/s]
# 20it [00:03,  6.22it/s]
# 21it [00:03,  6.78it/s]
# 22it [00:03,  7.31it/s]
# 23it [00:03,  7.67it/s]
# reading instances: 5888it [00:03, 1967.25it/s]
# 24it [00:03,  5.56it/s]
# 25it [00:03,  6.26it/s]
# 26it [00:03,  6.85it/s]
# 27it [00:04,  7.12it/s]
# 28it [00:04,  7.58it/s]
# reading instances: 7168it [00:04, 1942.84it/s]
# 29it [00:04,  5.48it/s]
# 30it [00:04,  6.13it/s]
# 31it [00:04,  6.67it/s]
# 32it [00:04,  7.10it/s]
# 33it [00:04,  7.52it/s]
# reading instances: 8448it [00:04, 1946.65it/s]
# 34it [00:05,  5.44it/s]
# 35it [00:05,  6.03it/s]
# 36it [00:05,  6.52it/s]
# 37it [00:05,  7.05it/s]
# 38it [00:05,  7.46it/s]
# reading instances: 9728it [00:05, 1932.93it/s]
# 39it [00:05,  5.42it/s]
# 40it [00:06,  6.12it/s]
# 41it [00:06,  6.75it/s]
# 42it [00:06,  7.22it/s]
# 43it [00:06,  7.71it/s]
# reading instances: 11008it [00:06, 2001.31it/s]
# 44it [00:06,  5.59it/s]
# 45it [00:06,  6.35it/s]
# 46it [00:06,  7.07it/s]
# 47it [00:07,  7.52it/s]
# 48it [00:07,  8.02it/s]
# 49it [00:07,  8.31it/s]
# reading instances: 12544it [00:07, 2067.78it/s]
# 50it [00:07,  5.76it/s]
# 51it [00:07,  6.51it/s]
# 52it [00:07,  7.19it/s]
# 53it [00:07,  7.64it/s]
# 54it [00:08,  7.80it/s]
# 55it [00:08,  8.04it/s]
# 56it [00:08,  5.73it/s]
# 57it [00:08,  6.44it/s]
# 58it [00:08,  7.06it/s]
# 59it [00:08,  7.53it/s]
# 60it [00:08,  7.94it/s]
# 61it [00:08,  8.24it/s]
# reading instances: 15616it [00:08, 2104.57it/s]
# 62it [00:09,  5.75it/s]
# 63it [00:09,  6.43it/s]
# 64it [00:09,  7.07it/s]
# reading instances: 2560it [00:03, 809.43it/s]
# reading instances: 2703it [00:03, 949.26it/s]
# 11it [00:03,  2.78it/s]
# reading instances: 2896it [00:03, 697.61it/s]
# 12it [00:04,  3.12it/s]
# reading instances: 3162it [00:04, 858.01it/s]
# 13it [00:04,  3.41it/s]
# reading instances: 3438it [00:04, 676.82it/s]
# 14it [00:04,  2.99it/s]
# reading instances: 3683it [00:04, 786.51it/s]
# 15it [00:04,  3.23it/s]
# reading instances: 3936it [00:05, 856.39it/s]
# 16it [00:05,  2.83it/s]
# reading instances: 4115it [00:05, 636.85it/s]
# 17it [00:05,  3.08it/s]
# reading instances: 4352it [00:05, 760.00it/s]
# reading instances: 4490it [00:05, 900.80it/s]
# 18it [00:06,  2.75it/s]
# reading instances: 4675it [00:06, 648.07it/s]
# 19it [00:06,  2.97it/s]
# reading instances: 4902it [00:06, 734.49it/s]
# 20it [00:06,  2.67it/s]
# reading instances: 5130it [00:06, 560.60it/s]
# 21it [00:07,  2.94it/s]
# reading instances: 5376it [00:07, 710.92it/s]
# 22it [00:07,  3.20it/s]
# reading instances: 5632it [00:07, 830.20it/s]
# reading instances: 5728it [00:07, 637.06it/s]
# 23it [00:07,  2.83it/s]
# 24it [00:07,  3.29it/s]
# 25it [00:08,  4.00it/s]
# reading instances: 6400it [00:08, 1218.94it/s]
# 26it [00:08,  3.71it/s]
# 27it [00:08,  4.42it/s]
# 28it [00:08,  5.07it/s]
# 29it [00:08,  5.69it/s]
# 30it [00:08,  6.23it/s]
# reading instances: 7680it [00:08, 1738.29it/s]
# 31it [00:09,  4.81it/s]
# 32it [00:09,  5.45it/s]
# 33it [00:09,  6.01it/s]
# 34it [00:09,  6.39it/s]
# 35it [00:09,  6.72it/s]
# reading instances: 8960it [00:09, 1769.48it/s]
# 36it [00:10,  4.48it/s]
# reading instances: 9287it [00:10, 1140.35it/s]
# 37it [00:10,  4.42it/s]
# reading instances: 9577it [00:10, 1124.82it/s]
# 38it [00:10,  3.48it/s]
# reading instances: 9802it [00:10, 808.90it/s]
# 39it [00:11,  3.74it/s]
# 40it [00:11,  3.94it/s]
# reading instances: 10240it [00:11, 946.91it/s]
# 41it [00:11,  3.28it/s]
# reading instances: 10496it [00:11, 762.55it/s]
# 42it [00:11,  3.57it/s]
# reading instances: 10760it [00:11, 896.44it/s]
# 43it [00:12,  3.80it/s]
# reading instances: 11044it [00:12, 708.86it/s]
# 44it [00:12,  3.24it/s]
# reading instances: 11305it [00:12, 838.43it/s]
# 45it [00:12,  3.41it/s]
# reading instances: 11560it [00:12, 890.98it/s]
# 46it [00:13,  3.00it/s]
# reading instances: 11776it [00:13, 707.83it/s]
# 47it [00:13,  3.28it/s]
# reading instances: 12032it [00:13, 840.99it/s]
# 48it [00:13,  2.92it/s]
# reading instances: 12291it [00:13, 643.96it/s]
# 49it [00:14,  3.23it/s]
# reading instances: 12562it [00:14, 812.37it/s]
# 50it [00:14,  3.49it/s]
# 87it [00:25,  2.97it/s]
# reading instances: 22311it [00:26, 678.39it/s]
# 88it [00:26,  3.28it/s]
# reading instances: 22581it [00:26, 829.09it/s]
# 89it [00:26,  3.56it/s]
# reading instances: 22861it [00:26, 962.43it/s]
# 90it [00:26,  3.13it/s]
# reading instances: 23063it [00:26, 732.03it/s]
# 91it [00:27,  3.43it/s]
# reading instances: 23330it [00:27, 878.70it/s]
# 92it [00:27,  3.00it/s]
# reading instances: 23605it [00:27, 664.50it/s]
# 93it [00:27,  3.26it/s]
# reading instances: 23863it [00:27, 803.63it/s]
# 94it [00:27,  3.51it/s]
# reading instances: 24189it [00:28, 862.00it/s]
# 95it [00:28,  3.38it/s]
# 0it [00:00, ?it/s]
# reading instances: 0it [00:00, ?it/s]
# reading instances: 5it [00:00, 25.23it/s]
# 1it [00:00,  2.18it/s]
# reading instances: 256it [00:00, 660.03it/s]
# 2it [00:00,  3.00it/s]
# reading instances: 512it [00:00, 853.81it/s]
# reading instances: 606it [00:00, 622.81it/s]
# 3it [00:01,  2.66it/s]
# reading instances: 852it [00:01, 762.28it/s]
# 4it [00:01,  2.96it/s]
# reading instances: 1063it [00:01, 797.59it/s]
# reading instances: 1151it [00:01, 589.92it/s]
# 5it [00:01,  2.62it/s]
# reading instances: 1361it [00:01, 708.82it/s]
# 6it [00:02,  2.98it/s]
# reading instances: 1607it [00:02, 840.33it/s]
# 7it [00:02,  2.69it/s]
# reading instances: 1823it [00:02, 643.86it/s]
# 8it [00:02,  2.91it/s]
# reading instances: 2048it [00:02, 736.33it/s]
# 9it [00:03,  3.20it/s]
# reading instances: 2304it [00:03, 857.15it/s]
# reading instances: 2398it [00:03, 648.51it/s]
# 10it [00:03,  2.85it/s]
# reading instances: 2634it [00:03, 772.23it/s]
# 11it [00:03,  3.14it/s]
# reading instances: 2884it [00:03, 870.48it/s]
# 12it [00:04,  2.87it/s]
# reading instances: 3072it [00:04, 675.82it/s]
# 13it [00:04,  3.20it/s]
# reading instances: 3337it [00:04, 847.62it/s]
# 14it [00:04,  2.87it/s]
# reading instances: 3608it [00:04, 648.60it/s]
# 15it [00:05,  3.12it/s]
# reading instances: 3849it [00:05, 759.31it/s]
# 16it [00:05,  3.29it/s]
# reading instances: 4096it [00:05, 834.04it/s]
# reading instances: 4192it [00:05, 638.70it/s]
# 17it [00:05,  2.89it/s]
# reading instances: 4426it [00:05, 750.25it/s]
# 18it [00:06,  3.12it/s]
# reading instances: 4667it [00:06, 822.19it/s]
# 19it [00:06,  2.78it/s]
# reading instances: 4864it [00:06, 641.15it/s]
# 20it [00:06,  2.99it/s]
# reading instances: 5120it [00:06, 758.86it/s]
# reading instances: 5247it [00:06, 868.69it/s]
# 21it [00:07,  2.69it/s]
# reading instances: 5425it [00:07, 639.80it/s]
# 22it [00:07,  2.98it/s]
# reading instances: 5658it [00:07, 762.36it/s]
# reading instances: 5771it [00:07, 847.10it/s]
# 23it [00:07,  2.62it/s]
# 24it [00:08,  3.09it/s]
# 25it [00:08,  3.79it/s]
# 26it [00:08,  4.52it/s]
# 27it [00:08,  5.19it/s]
# reading instances: 6912it [00:08, 1563.24it/s]
# 28it [00:08,  4.39it/s]
# 29it [00:09,  5.02it/s]
# 30it [00:09,  5.64it/s]
# 31it [00:09,  6.13it/s]
# reading instances: 7936it [00:09, 1685.78it/s]
# 32it [00:09,  4.78it/s]
# 33it [00:09,  5.40it/s]
# 34it [00:09,  5.91it/s]
# 35it [00:09,  6.24it/s]
# reading instances: 8960it [00:09, 1618.08it/s]
# 36it [00:10,  4.25it/s]
# reading instances: 9313it [00:10, 988.04it/s]
# 37it [00:10,  4.26it/s]
# 38it [00:10,  4.33it/s]
# reading instances: 9735it [00:10, 992.84it/s]
# 39it [00:11,  3.52it/s]
# reading instances: 9984it [00:11, 807.01it/s]
# 40it [00:11,  3.74it/s]
# reading instances: 10248it [00:11, 916.87it/s]
# 41it [00:11,  3.17it/s]
# reading instances: 10528it [00:11, 694.94it/s]
# 42it [00:12,  3.47it/s]
# reading instances: 10804it [00:12, 859.21it/s]
# 43it [00:12,  3.73it/s]
# reading instances: 11089it [00:12, 975.74it/s]
# 44it [00:12,  3.17it/s]
# reading instances: 11292it [00:12, 718.92it/s]
# 45it [00:13,  3.39it/s]
# reading instances: 11535it [00:13, 827.24it/s]
# 46it [00:13,  2.96it/s]
# reading instances: 11793it [00:13, 633.49it/s]
# 47it [00:13,  3.26it/s]
# reading instances: 12054it [00:13, 792.92it/s]
# 48it [00:13,  3.51it/s]
# reading instances: 12321it [00:13, 912.05it/s]
# 49it [00:14,  3.07it/s]
# reading instances: 12544it [00:14, 725.07it/s]
# 50it [00:14,  3.35it/s]
# reading instances: 12800it [00:14, 856.60it/s]
# 51it [00:15,  2.96it/s]
# reading instances: 13058it [00:15, 651.30it/s]
# 52it [00:15,  3.29it/s]
# reading instances: 13338it [00:15, 831.61it/s]
# 53it [00:15,  3.56it/s]
# reading instances: 13618it [00:15, 955.95it/s]
# 54it [00:15,  3.12it/s]
# reading instances: 13824it [00:15, 732.97it/s]
# 55it [00:16,  3.46it/s]
# reading instances: 14097it [00:16, 904.78it/s]
# 56it [00:16,  3.69it/s]
# reading instances: 14372it [00:16, 997.00it/s]
# 57it [00:16,  3.17it/s]
# reading instances: 14592it [00:16, 748.30it/s]
# 58it [00:16,  3.44it/s]
# reading instances: 14848it [00:16, 879.73it/s]
# 59it [00:17,  3.02it/s]
# reading instances: 15112it [00:17, 664.59it/s]
# 60it [00:17,  3.32it/s]
# reading instances: 15376it [00:17, 824.71it/s]
# 61it [00:17,  3.58it/s]
# reading instances: 15647it [00:17, 936.45it/s]
# 62it [00:18,  3.11it/s]
# reading instances: 15872it [00:18, 737.22it/s]
# 63it [00:18,  3.42it/s]
# reading instances: 16143it [00:18, 891.71it/s]
# 64it [00:18,  3.03it/s]
# reading instances: 16384it [00:18, 737.70it/s]
# 65it [00:19,  3.34it/s]
# reading instances: 16649it [00:19, 872.34it/s]
# 66it [00:19,  2.98it/s]
# reading instances: 16928it [00:19, 685.66it/s]
# 67it [00:19,  3.31it/s]
# reading instances: 17205it [00:19, 851.08it/s]
# 68it [00:20,  3.56it/s]
# reading instances: 17484it [00:20, 932.82it/s]
# 69it [00:20,  3.05it/s]
# reading instances: 17680it [00:20, 699.62it/s]
# 70it [00:20,  3.33it/s]
# reading instances: 17933it [00:20, 836.06it/s]
# 71it [00:21,  2.93it/s]
# reading instances: 18183it [00:21, 633.17it/s]
# 72it [00:21,  3.25it/s]
# reading instances: 18438it [00:21, 797.89it/s]
# 73it [00:21,  3.51it/s]
# reading instances: 18708it [00:21, 922.07it/s]
# 74it [00:22,  3.07it/s]
# reading instances: 18944it [00:22, 743.59it/s]
# 75it [00:22,  3.38it/s]
# reading instances: 19216it [00:22, 890.56it/s]
# 76it [00:22,  3.03it/s]
# reading instances: 19502it [00:22, 701.02it/s]
# 77it [00:22,  3.33it/s]
# reading instances: 19773it [00:22, 852.04it/s]
# 78it [00:23,  3.62it/s]
# 79it [00:23,  3.18it/s]
# reading instances: 20224it [00:23, 778.01it/s]
# 80it [00:23,  3.45it/s]
# reading instances: 20499it [00:23, 895.43it/s]
# 81it [00:24,  3.01it/s]
# reading instances: 20767it [00:24, 680.19it/s]
# 82it [00:24,  3.29it/s]
# reading instances: 21030it [00:24, 816.16it/s]
# 83it [00:24,  3.55it/s]
# reading instances: 21304it [00:24, 930.88it/s]
# 84it [00:25,  3.11it/s]
# reading instances: 21504it [00:25, 717.58it/s]
# 85it [00:25,  3.39it/s]
# reading instances: 21762it [00:25, 857.23it/s]
# 86it [00:25,  3.00it/s]
# reading instances: 22016it [00:25, 719.30it/s]
# 87it [00:25,  3.33it/s]
# reading instances: 22287it [00:25, 880.36it/s]
# 88it [00:26,  3.59it/s]
# reading instances: 22567it [00:26, 693.58it/s]
# 89it [00:26,  3.16it/s]
# reading instances: 22842it [00:26, 866.38it/s]
# 90it [00:26,  3.44it/s]
# reading instances: 23114it [00:26, 957.77it/s]
# 91it [00:27,  3.05it/s]
# reading instances: 23313it [00:27, 722.02it/s]
# 92it [00:27,  3.35it/s]
# reading instances: 23579it [00:27, 868.00it/s]
# 93it [00:27,  2.96it/s]
# reading instances: 23808it [00:27, 697.99it/s]
# 94it [00:28,  3.24it/s]
# reading instances: 24189it [00:28, 857.96it/s]
# 95it [00:28,  3.36it/s]
# MSMarco metrics: {'MRR@10': 0.278959126984127, 'Recall@10': 0.4949583333333333, 'QueriesWithNoRelevant@10': 999, 'QueriesWithRelevant@10': 1001, 'AverageRankGoldLabel@10': 3.128871128871129, 'MedianRankGoldLabel@10': 2.0, 'MRR@20': 0.2838755692342573, 'Recall@20': 0.5644166666666668, 'QueriesWithNoRelevant@20': 858, 'QueriesWithRelevant@20': 1142, 'AverageRankGoldLabel@20': 4.587565674255692, 'MedianRankGoldLabel@20': 3.0, 'MRR@1000': 0.2851484426801613, 'Recall@1000': 0.6002916666666668, 'QueriesWithNoRelevant@1000': 788, 'QueriesWithRelevant@1000': 1212, 'AverageRankGoldLabel@1000': 5.963696369636963, 'MedianRankGoldLabel@1000': 3.0, 'nDCG@3': 0.27037205359351596, 'nDCG@5': 0.3003718305083099, 'nDCG@10': 0.32911543600391163, 'nDCG@20': 0.34693789013860776, 'nDCG@1000': 0.35447183872949234, 'QueriesRanked': 2000, 'MAP@1000': 0.281939943312788}
# Fira metrics: {'MRR@10': 0.9309903041676441, 'Recall@10': 0.9406342631096326, 'QueriesWithNoRelevant@10': 116, 'QueriesWithRelevant@10': 4059, 'AverageRankGoldLabel@10': 1.165311653116531, 'MedianRankGoldLabel@10': 1.0, 'MRR@20': 0.9310126955693458, 'Recall@20': 1.0, 'QueriesWithNoRelevant@20': 115, 'QueriesWithRelevant@20': 4060, 'AverageRankGoldLabel@20': 1.1677339901477832, 'MedianRankGoldLabel@20': 1.0, 'MRR@1000': 0.9310126955693458, 'Recall@1000': 1.0, 'QueriesWithNoRelevant@1000': 115, 'QueriesWithRelevant@1000': 4060, 'AverageRankGoldLabel@1000': 1.1677339901477832, 'MedianRankGoldLabel@1000': 1.0, 'nDCG@3': 0.842653047944616, 'nDCG@5': 0.8478881518857333, 'nDCG@10': 0.8755269292468056, 'nDCG@20': 0.8953634207997108, 'nDCG@1000': 0.8953634207997108, 'QueriesRanked': 4060, 'MAP@1000': 0.9185537621927028}
# Custom Fira metrics: {'MRR@10': 0.9363360433604335, 'Recall@10': 0.940598828001267, 'QueriesWithNoRelevant@10': 77, 'QueriesWithRelevant@10': 4098, 'AverageRankGoldLabel@10': 1.1478770131771596, 'MedianRankGoldLabel@10': 1.0, 'MRR@20': 0.9363785415126878, 'Recall@20': 1.0, 'QueriesWithNoRelevant@20': 75, 'QueriesWithRelevant@20': 4100, 'AverageRankGoldLabel@20': 1.1529268292682926, 'MedianRankGoldLabel@20': 1.0, 'MRR@1000': 0.9363785415126878, 'Recall@1000': 1.0, 'QueriesWithNoRelevant@1000': 75, 'QueriesWithRelevant@1000': 4100, 'AverageRankGoldLabel@1000': 1.1529268292682926, 'MedianRankGoldLabel@1000': 1.0, 'nDCG@3': 0.8396139603725219, 'nDCG@5': 0.8490468515284291, 'nDCG@10': 0.8774489321014304, 'nDCG@20': 0.896925733549794, 'nDCG@1000': 0.896925733549794, 'QueriesRanked': 4100, 'MAP@1000': 0.923624732454746}

# %% [markdown]
# # Evaluate log qrels

# %%
model.load_state_dict(torch.load(config["model_path"]))
custom_log_fira_eval, _ = evaluate_model(fira_loader, custom_qrels_log)
print(f"Custom Fira metrics with np.log1p: {custom_log_fira_eval}")
# Out:
# 0it [00:00, ?it/s]
# reading instances: 0it [00:00, ?it/s]
# reading instances: 122it [00:00, 1215.21it/s]
# 1it [00:00,  3.68it/s]
# reading instances: 382it [00:00, 1029.76it/s]
# 2it [00:00,  2.73it/s]
# reading instances: 571it [00:00, 669.08it/s]
# 3it [00:00,  3.22it/s]
# reading instances: 827it [00:00, 803.82it/s]
# 4it [00:01,  2.64it/s]
# reading instances: 1037it [00:01, 556.22it/s]
# 5it [00:01,  2.96it/s]
# reading instances: 1280it [00:01, 706.03it/s]
# 6it [00:01,  3.27it/s]
# reading instances: 1536it [00:01, 838.50it/s]
# reading instances: 1643it [00:02, 646.60it/s]
# 7it [00:02,  2.86it/s]
# reading instances: 1878it [00:02, 748.21it/s]
# 8it [00:02,  3.05it/s]
# reading instances: 2092it [00:02, 800.03it/s]
# 9it [00:03,  2.75it/s]
# reading instances: 2304it [00:03, 642.17it/s]
# 10it [00:03,  3.04it/s]
# reading instances: 2560it [00:03, 786.84it/s]
# reading instances: 2702it [00:03, 928.82it/s]
# 11it [00:03,  2.74it/s]
# reading instances: 2895it [00:03, 683.30it/s]
# 12it [00:04,  3.09it/s]
# reading instances: 3159it [00:04, 845.69it/s]
# 13it [00:04,  3.37it/s]
# reading instances: 3433it [00:04, 945.38it/s]
# 14it [00:04,  2.98it/s]
# reading instances: 3623it [00:04, 689.59it/s]
# 15it [00:04,  3.20it/s]
# reading instances: 3850it [00:04, 778.90it/s]
# reading instances: 3980it [00:05, 899.35it/s]
# 16it [00:05,  2.79it/s]
# reading instances: 4161it [00:05, 641.33it/s]
# 17it [00:05,  3.06it/s]
# reading instances: 4396it [00:05, 767.15it/s]
# 18it [00:05,  3.27it/s]
# reading instances: 4639it [00:05, 846.79it/s]
# reading instances: 4732it [00:06, 635.94it/s]
# 19it [00:06,  2.88it/s]
# reading instances: 4953it [00:06, 734.18it/s]
# 20it [00:06,  3.07it/s]
# reading instances: 5186it [00:06, 792.52it/s]
# 21it [00:07,  2.77it/s]
# reading instances: 5376it [00:07, 627.61it/s]
# 22it [00:07,  3.04it/s]
# reading instances: 5632it [00:07, 781.65it/s]
# 23it [00:07,  2.74it/s]
# reading instances: 5888it [00:07, 668.55it/s]
# 24it [00:07,  3.17it/s]
# 25it [00:08,  3.86it/s]
# 26it [00:08,  4.57it/s]
# reading instances: 6656it [00:08, 1438.87it/s]
# 27it [00:08,  4.06it/s]
# 28it [00:08,  4.75it/s]
# 29it [00:08,  5.42it/s]
# 30it [00:08,  5.97it/s]
# 31it [00:09,  4.69it/s]
# 32it [00:09,  5.38it/s]
# 33it [00:09,  5.97it/s]
# 34it [00:09,  6.36it/s]
# 35it [00:09,  6.75it/s]
# reading instances: 8960it [00:09, 1761.67it/s]
# 36it [00:10,  4.47it/s]
# reading instances: 9300it [00:10, 1156.85it/s]
# 37it [00:10,  4.41it/s]
# 38it [00:10,  4.46it/s]
# reading instances: 9728it [00:10, 1073.06it/s]
# 39it [00:11,  3.61it/s]
# reading instances: 9984it [00:11, 849.85it/s]
# 40it [00:11,  3.81it/s]
# reading instances: 10254it [00:11, 944.39it/s]
# 41it [00:11,  3.26it/s]
# reading instances: 10496it [00:11, 768.92it/s]
# 42it [00:11,  3.53it/s]
# reading instances: 10765it [00:11, 897.98it/s]
# 43it [00:12,  3.06it/s]
# reading instances: 11044it [00:12, 684.84it/s]
# 44it [00:12,  3.37it/s]
# reading instances: 11316it [00:12, 833.80it/s]
# 45it [00:12,  3.56it/s]
# reading instances: 11574it [00:12, 911.82it/s]
# 46it [00:13,  3.07it/s]
# reading instances: 11776it [00:13, 698.56it/s]
# 47it [00:13,  3.35it/s]
# reading instances: 12032it [00:13, 841.67it/s]
# 48it [00:13,  2.94it/s]
# reading instances: 12291it [00:13, 636.35it/s]
# 49it [00:14,  3.24it/s]
# reading instances: 12556it [00:14, 798.29it/s]
# 50it [00:14,  3.50it/s]
# reading instances: 12826it [00:14, 918.17it/s]
# 51it [00:14,  3.10it/s]
# reading instances: 13056it [00:14, 740.62it/s]
# 52it [00:14,  3.40it/s]
# reading instances: 13339it [00:14, 894.61it/s]
# 53it [00:15,  3.58it/s]
# reading instances: 13613it [00:15, 681.91it/s]
# 54it [00:15,  3.16it/s]
# reading instances: 13890it [00:15, 845.14it/s]
# 55it [00:15,  3.44it/s]
# reading instances: 14169it [00:15, 953.08it/s]
# 56it [00:16,  3.01it/s]
# reading instances: 14368it [00:16, 713.04it/s]
# 57it [00:16,  3.30it/s]
# reading instances: 14625it [00:16, 849.41it/s]
# 58it [00:16,  2.89it/s]
# reading instances: 14877it [00:16, 626.42it/s]
# 59it [00:17,  3.18it/s]
# reading instances: 15126it [00:17, 773.87it/s]
# 60it [00:17,  3.43it/s]
# reading instances: 15388it [00:17, 889.16it/s]
# 61it [00:17,  3.04it/s]
# reading instances: 15616it [00:17, 725.16it/s]
# 62it [00:18,  3.35it/s]
# reading instances: 15881it [00:18, 875.57it/s]
# 63it [00:18,  2.97it/s]
# reading instances: 16161it [00:18, 676.98it/s]
# 64it [00:18,  3.31it/s]
# reading instances: 16446it [00:18, 851.74it/s]
# 65it [00:18,  3.56it/s]
# reading instances: 16726it [00:19, 958.10it/s]
# 66it [00:19,  3.13it/s]
# reading instances: 16928it [00:19, 733.76it/s]
# 67it [00:19,  3.44it/s]
# reading instances: 17203it [00:19, 896.76it/s]
# 68it [00:20,  3.02it/s]
# reading instances: 17488it [00:20, 684.91it/s]
# 69it [00:20,  3.30it/s]
# reading instances: 17747it [00:20, 821.47it/s]
# 70it [00:20,  3.55it/s]
# reading instances: 18017it [00:20, 928.13it/s]
# 71it [00:20,  3.05it/s]
# reading instances: 18211it [00:20, 683.93it/s]
# 72it [00:21,  3.35it/s]
# reading instances: 18473it [00:21, 845.19it/s]
# 73it [00:21,  2.97it/s]
# reading instances: 18739it [00:21, 656.86it/s]
# 74it [00:21,  3.30it/s]
# reading instances: 19016it [00:21, 815.07it/s]
# 75it [00:22,  3.53it/s]
# 76it [00:22,  3.09it/s]
# reading instances: 19456it [00:22, 745.23it/s]
# 77it [00:22,  3.40it/s]
# reading instances: 19731it [00:22, 882.58it/s]
# 78it [00:23,  3.02it/s]
# reading instances: 20022it [00:23, 701.78it/s]
# 79it [00:23,  3.34it/s]
# reading instances: 20305it [00:23, 860.06it/s]
# 80it [00:23,  3.61it/s]
# reading instances: 20590it [00:23, 699.54it/s]
# 81it [00:23,  3.11it/s]
# 82it [00:24,  3.38it/s]
# reading instances: 20992it [00:24, 842.85it/s]
# 83it [00:24,  2.98it/s]
# reading instances: 21257it [00:24, 660.62it/s]
# 84it [00:24,  3.31it/s]
# reading instances: 21532it [00:24, 828.20it/s]
# 85it [00:25,  3.55it/s]
# reading instances: 21804it [00:25, 931.87it/s]
# 86it [00:25,  3.11it/s]
# reading instances: 22016it [00:25, 731.53it/s]
# 87it [00:25,  3.43it/s]
# reading instances: 22296it [00:25, 898.97it/s]
# 88it [00:26,  3.00it/s]
# reading instances: 22572it [00:26, 673.97it/s]
# 89it [00:26,  3.32it/s]
# reading instances: 22851it [00:26, 851.45it/s]
# 90it [00:26,  3.61it/s]
# 91it [00:27,  3.17it/s]
# reading instances: 23296it [00:27, 769.52it/s]
# 92it [00:27,  3.41it/s]
# reading instances: 23552it [00:27, 870.81it/s]
# 93it [00:27,  3.01it/s]
# reading instances: 23816it [00:27, 671.45it/s]
# 94it [00:27,  3.23it/s]
# reading instances: 24189it [00:28, 862.33it/s]
# 95it [00:28,  3.38it/s]
# Custom Fira metrics with np.log1p: {'MRR@10': 0.939856925843254, 'Recall@10': 0.9408800529711174, 'QueriesWithNoRelevant@10': 80, 'QueriesWithRelevant@10': 4095, 'AverageRankGoldLabel@10': 1.143101343101343, 'MedianRankGoldLabel@10': 1.0, 'MRR@20': 0.9398791204455267, 'Recall@20': 1.0, 'QueriesWithNoRelevant@20': 79, 'QueriesWithRelevant@20': 4096, 'AverageRankGoldLabel@20': 1.1455078125, 'MedianRankGoldLabel@20': 1.0, 'MRR@1000': 0.9398791204455267, 'Recall@1000': 1.0, 'QueriesWithNoRelevant@1000': 79, 'QueriesWithRelevant@1000': 4096, 'AverageRankGoldLabel@1000': 1.1455078125, 'MedianRankGoldLabel@1000': 1.0, 'nDCG@3': 0.8484802235896395, 'nDCG@5': 0.8583890503971509, 'nDCG@10': 0.8842504576080512, 'nDCG@20': 0.9024749796866838, 'nDCG@1000': 0.9024749796866838, 'QueriesRanked': 4096, 'MAP@1000': 0.928988627689344}

# %% [markdown]
# # Extract and save top1 MSMarco

# %%
top1_results = {qid: did[0] for qid, did in ranked_results.items()}
df_top1 = pd.DataFrame(list(top1_results.items()), columns=['query_id', 'doc_id'])
df_top1.to_csv('/content/drive/MyDrive/AIR/data/Part-2/top1_results_tk.csv', index=False)

# %%
top2_results = {qid: (did[0], did[1]) for qid, did in ranked_results.items()}
print(top2_results)
df_top2 = pd.DataFrame([(qid, dids[0], dids[1]) for qid, dids in top2_results.items()], columns=['query_id', 'doc1_id', 'doc2_id'])
df_top2.to_csv('/content/drive/MyDrive/AIR/data/Part-2/top2_results_tk.csv', index=False)
